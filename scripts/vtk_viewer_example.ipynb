# %% [markdown]
# # COVID-CT VTK Viewer - Jupyter Notebook Example
#
# This notebook demonstrates the VTK-based viewer for CT images, segmentation masks, and registration comparison.

# %%
import sys
import os
sys.path.append('..')

from scripts.vtk_viewer_notebook import create_slice_viewer, create_comparison_viewer
from IPython.display import display

# %% [markdown]
# ## Step 1: Axial Slice Viewer with Segmentation Overlay
#
# Load your original CT image and segmentation mask to view slices with overlay.

# %%
# Update these paths to your actual files
image_path = "data/processed/case1/image_resampled.nii.gz"
mask_path = "data/processed/case1/mask_infection.nii.gz"

# Create and display the viewer
viewer = create_slice_viewer(image_path, mask_path)
display(viewer)

# %% [markdown]
# ## Step 2: Before vs After Registration Comparison
#
# Compare original and registered images using checkerboard, difference map, or side-by-side view.

# %%
# Update these paths to your actual files
original_path = "data/processed/case1/image_resampled.nii.gz"
registered_path = "data/processed/case1/moving_rigid.nii.gz"

# Create and display the comparison viewer
comp_viewer = create_comparison_viewer(original_path, registered_path)
display(comp_viewer)
